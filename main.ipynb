# %%
# %matplotlib inline
from ply2voxilize import voxilize, voxel_scatter
from load_ply import load_ply
from plot_fig import plot3D, plot_trihedral_figure , plot_trihedral_figure_vox
import matplotlib.pyplot as plt
# import torch

# %%
#plot point_cloud
np_pc = load_ply("bathtub_0107.ply")
plot3D(np_pc)
plot_trihedral_figure(np_pc)

# %%
#voxelize
np_vox = voxilize(np_pc)

# %%
#turn
vox_scat = voxel_scatter(np_vox)
plot3D(vox_scat)
plot_trihedral_figure_vox(vox_scat)
